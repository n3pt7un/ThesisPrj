# %%
import pandas as pd
import fastf1 
import numpy as np

# %% [markdown]
# # Limiting the timeframe of interest
# In order to limit the timeframe of interest for the reserch we will only focus on the past 5 completed seasons of F1, namely 2018-2024.
# To do so we first need to collect a complete calendar of all the events ran in this timeframe

# %%
import fastf1.events

# Collecting the calendar
complete_calendar = fastf1.events.get_event_schedule(2018)

for year in range(2019, 2025):
    complete_calendar = pd.concat([complete_calendar, fastf1.events.get_event_schedule(year)])

complete_calendar.head()
# Out:
# req         WARNING 	DEFAULT CACHE ENABLED! (24.0 KB) C:\Users\vnvtr\AppData\Local\Temp\fastf1
#    RoundNumber     Country   Location  \
# 0            1   Australia  Melbourne
# 1            2     Bahrain     Sakhir
# 2            3       China   Shanghai
# 3            4  Azerbaijan       Baku
# 4            5       Spain  Barcelona
#
#                                OfficialEventName  EventDate  \
# 0     FORMULA 1 2018 ROLEX AUSTRALIAN GRAND PRIX 2018-03-25
# 1     FORMULA 1 2018 GULF AIR BAHRAIN GRAND PRIX 2018-04-08
# 2     FORMULA 1 2018 HEINEKEN CHINESE GRAND PRIX 2018-04-15
# 3           FORMULA 1 2018 AZERBAIJAN GRAND PRIX 2018-04-29
# 4  FORMULA 1 GRAN PREMIO DE ESPAÑA EMIRATES 2018 2018-05-13
#
#                EventName   EventFormat    Session1               Session1Date  \
# 0  Australian Grand Prix  conventional  Practice 1  2018-03-23 12:00:00+11:00
# 1     Bahrain Grand Prix  conventional  Practice 1  2018-04-06 14:00:00+03:00
# 2     Chinese Grand Prix  conventional  Practice 1  2018-04-13 10:00:00+08:00
# 3  Azerbaijan Grand Prix  conventional  Practice 1  2018-04-27 13:00:00+04:00
# 4     Spanish Grand Prix  conventional  Practice 1  2018-05-11 11:00:00+02:00
#
#       Session1DateUtc  ...    Session3               Session3Date  \
# 0 2018-03-23 01:00:00  ...  Practice 3  2018-03-24 14:00:00+11:00
# 1 2018-04-06 11:00:00  ...  Practice 3  2018-04-07 15:00:00+03:00
# 2 2018-04-13 02:00:00  ...  Practice 3  2018-04-14 11:00:00+08:00
# 3 2018-04-27 09:00:00  ...  Practice 3  2018-04-28 14:00:00+04:00
# 4 2018-05-11 09:00:00  ...  Practice 3  2018-05-12 12:00:00+02:00
#
#       Session3DateUtc    Session4               Session4Date  \
# 0 2018-03-24 03:00:00  Qualifying  2018-03-24 17:00:00+11:00
# 1 2018-04-07 12:00:00  Qualifying  2018-04-07 18:00:00+03:00
# 2 2018-04-14 03:00:00  Qualifying  2018-04-14 14:00:00+08:00
# 3 2018-04-28 10:00:00  Qualifying  2018-04-28 17:00:00+04:00
# 4 2018-05-12 10:00:00  Qualifying  2018-05-12 15:00:00+02:00
#
#       Session4DateUtc Session5               Session5Date     Session5DateUtc  \
# 0 2018-03-24 06:00:00     Race  2018-03-25 16:10:00+11:00 2018-03-25 05:10:00
# 1 2018-04-07 15:00:00     Race  2018-04-08 18:10:00+03:00 2018-04-08 15:10:00
# 2 2018-04-14 06:00:00     Race  2018-04-15 14:10:00+08:00 2018-04-15 06:10:00
# 3 2018-04-28 13:00:00     Race  2018-04-29 16:10:00+04:00 2018-04-29 12:10:00
# 4 2018-05-12 13:00:00     Race  2018-05-13 15:10:00+02:00 2018-05-13 13:10:00
#
#   F1ApiSupport
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#
# [5 rows x 23 columns]

# %%
complete_calendar['EventFormat'].value_counts()
# Out:
# EventFormat
# conventional         131
# testing                7
# sprint                 6
# sprint_shootout        6
# sprint_qualifying      6
# Name: count, dtype: int64

# %% [markdown]
# Now lets remove testing sessions from the calendar since information may be incomplete and any insights may be biased because of 'bagging' practices.

# %%
complete_calendar = complete_calendar[complete_calendar['EventFormat'].str.contains('testing') == False]
complete_calendar['EventFormat'].value_counts()
# Out:
# EventFormat
# conventional         131
# sprint                 6
# sprint_shootout        6
# sprint_qualifying      6
# Name: count, dtype: int64

# %% [markdown]
# Lets inspect the 3 different types of sprint events and verify that they are actually different event formats.

# %%
complete_calendar[complete_calendar['EventFormat'].str.contains('sprint')]
# Out:
#     RoundNumber        Country           Location  \
# 10           10  Great Britain        Silverstone
# 14           14          Italy              Monza
# 19           19         Brazil          São Paulo
# 5             4          Italy              Imola
# 12           11        Austria          Spielberg
# 22           21         Brazil          São Paulo
# 4             4     Azerbaijan               Baku
# 9             9        Austria          Spielberg
# 12           12        Belgium  Spa-Francorchamps
# 17           17          Qatar             Lusail
# 18           18  United States             Austin
# 20           20         Brazil          São Paulo
# 5             5          China           Shanghai
# 6             6  United States              Miami
# 11           11        Austria          Spielberg
# 19           19  United States             Austin
# 21           21         Brazil          São Paulo
# 23           23          Qatar             Lusail
#
#                                     OfficialEventName  EventDate  \
# 10          FORMULA 1 PIRELLI BRITISH GRAND PRIX 2021 2021-07-18
# 14       FORMULA 1 HEINEKEN GRAN PREMIO D’ITALIA 2021 2021-09-12
# 19  FORMULA 1 HEINEKEN GRANDE PRÊMIO DE SÃO PAULO ... 2021-11-14
# 5   FORMULA 1 ROLEX GRAN PREMIO DEL MADE IN ITALY ... 2022-04-24
# 12  FORMULA 1 ROLEX GROSSER PREIS VON ÖSTERREICH 2022 2022-07-10
# 22  FORMULA 1 HEINEKEN GRANDE PRÊMIO DE SÃO PAULO ... 2022-11-13
# 4                FORMULA 1 AZERBAIJAN GRAND PRIX 2023 2023-04-30
# 9   FORMULA 1 ROLEX GROSSER PREIS VON ÖSTERREICH 2023 2023-07-02
# 12      FORMULA 1 MSC CRUISES BELGIAN GRAND PRIX 2023 2023-07-30
# 17      FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2023 2023-10-08
# 18     FORMULA 1 LENOVO UNITED STATES GRAND PRIX 2023 2023-10-22
# 20    FORMULA 1 ROLEX GRANDE PRÊMIO DE SÃO PAULO 2023 2023-11-05
# 5            FORMULA 1 LENOVO CHINESE GRAND PRIX 2024 2024-04-21
# 6          FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2024 2024-05-05
# 11   FORMULA 1 QATAR AIRWAYS AUSTRIAN GRAND PRIX 2024 2024-06-30
# 19    FORMULA 1 PIRELLI UNITED STATES GRAND PRIX 2024 2024-10-20
# 21   FORMULA 1 LENOVO GRANDE PRÊMIO DE SÃO PAULO 2024 2024-11-03
# 23      FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2024 2024-12-01
#
#                     EventName        EventFormat    Session1  \
# 10         British Grand Prix             sprint  Practice 1
# 14         Italian Grand Prix             sprint  Practice 1
# 11  2024-06-30 15:00:00+02:00 2024-06-30 13:00:00         True
# 19  2024-10-20 14:00:00-05:00 2024-10-20 19:00:00         True
# 21  2024-11-03 12:30:00-03:00 2024-11-03 15:30:00         True
# 23  2024-12-01 19:00:00+03:00 2024-12-01 16:00:00         True
#
# [18 rows x 23 columns]

# %% [markdown]
# Since the 3 different types of sprint events actually correspond to the same event format we are going to change the value of the variable 'EventFormat' to just 'spint'.

# %%
complete_calendar.loc[:, 'EventFormat'] = complete_calendar['EventFormat'].str.replace('sprint_qualifying', 'sprint')
complete_calendar.loc[:, 'EventFormat'] = complete_calendar['EventFormat'].str.replace('sprint_shootout', 'sprint')
complete_calendar['EventFormat'].value_counts()
# Out:
# EventFormat
# conventional    131
# sprint           18
# Name: count, dtype: int64

# %%
complete_calendar.to_csv('complete_calendar.csv', index=False)

# %% [markdown]
# # Extracting teams and drivers
# We can now extract drivers and team names by calling .get_drivers() for each event. To save on network usage we will locally cache the fastf1 data collected.

# %%
import fastf1.logger as logger
import logging


fastf1.logger.LoggingManager().set_level(logging.CRITICAL)

# %%
import pandas as pd
import fastf1
from tqdm.auto import tqdm # Import tqdm

# Assuming 'complete_calendar' DataFrame is loaded and preprocessed

fastf1.Cache.enable_cache('./cache')
fastf1.Cache.offline_mode(enabled=True)

# Extracting results from each race
results = []
failed_sessions = []

# Get the total number of events to process for the progress bar
total_events = len(complete_calendar) 

# Use tqdm by wrapping the iteration over the DataFrame rows
# Use .iterrows() to get both index and row data
print(f"Processing {total_events} events...")
for index, row in tqdm(complete_calendar.iterrows(), total=total_events, desc="Loading Race Results"):
    year = row['EventDate'].year # Extract year from the row
    event = row['EventName']     # Extract event name from the row
    race_identifier = f"{year} - {event}" # Create identifier

    try:
        session = fastf1.get_session(year, event, 'R')
        session.load() 
        
        event_results = session.results
        
        if event_results is not None and not event_results.empty:
            # Use .copy() to avoid potential SettingWithCopyWarning
            event_results = event_results.copy() 
            event_results['Event'] = event
            event_results['Year'] = year
            results.append(event_results)
        else:
            print(f"Warning: No results data found for {race_identifier}")
            failed_sessions.append(race_identifier + " (No results)")

    except Exception as e:
        print(f"Error loading session data for {race_identifier}: {e}")
        failed_sessions.append(f"{race_identifier} (Error: {e})")
# Out:
# Processing 149 events...
# Loading Race Results:   0%|          | 0/149 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 28
#      26 try:
#      27     session = fastf1.get_session(year, event, 'R')
# ---> 28     session.load()
#      30     event_results = session.results
#      32     if event_results is not None and not event_results.empty:
#      33         # Use .copy() to avoid potential SettingWithCopyWarning
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\core.py:1421, in Session.load(self, laps, telemetry, weather, messages, livedata)
#    1418     self._add_first_lap_time_from_ergast()
#    1420 if telemetry:
# -> 1421     self._load_telemetry(livedata=livedata)
#    1423 if weather:
#    1424     self._load_weather_data(livedata=livedata)
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\logger.py:151, in soft_exceptions.<locals>.__decorator.<locals>.__wrapped(*args, **kwargs)
#     149 if not LoggingManager.debug:
#     150     try:
# --> 151         return func(*args, **kwargs)
#     152     except Exception as exc:
#     153         logger.warning(msg)
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\core.py:2434, in Session._load_telemetry(self, livedata)
#    2408 """Load telemetry data from the API.
#    2409
#    2410 This method can only be called after :meth:`load_laps` has been
#    (...)
#    2431         saved livetiming data can be used as a data source
#    2432 """
#    2433 try:
# -> 2434     car_data = api.car_data(self.api_path, livedata=livedata)
#    2435 except api.SessionNotAvailableError:
#    2436     _logger.warning("Car telemetry data is unavailable!")
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\req.py:431, in Cache.api_request_wrapper.<locals>._cached_api_request(api_path, **func_kwargs)
#     428 else:
#     429     # cached data needs to be downloaded again and updated
#     430     _logger.info(f"Updating cache for {func_name}...")
# --> 431     data = func(api_path, **func_kwargs)
#     433     if data is not None:
#     434         cls._write_cache(data, cache_file_path)
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\_api.py:951, in car_data(path, response, livedata)
#     949 else:
#     950     time = to_timedelta(record[:ts_length])
# --> 951     jrecord: dict = parse(record[ts_length:], zipped=True)
#     953 for entry in jrecord['Entries']:
#     954     # date format is '2020-08-08T09:45:03.0619797Z' with a varying
#     955     # number of millisecond decimal points
#     956     # always remove last char ('z'), max len 26, right pad to len
#     957     # 26 with zeroes if shorter
#     958     date = to_datetime(entry['Utc'])
#
# File c:\Users\vnvtr\anaconda3\Lib\site-packages\fastf1\_api.py:1763, in parse(text, zipped)
#    1761     text = text.strip('"')
#    1762 if zipped:
# -> 1763     text = zlib.decompress(base64.b64decode(text), -zlib.MAX_WBITS)
#    1764     return parse(text.decode('utf-8-sig'))
#    1765 _logger.warning("Couldn't parse text")
#
# KeyboardInterrupt:

# %%
complete_results.to_csv('complete_results.csv', index=False)

# %% [markdown]
# # Checkpoint: reading complete results

# %%
complete_results = pd.read_csv('complete_results.csv')
complete_results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2979 entries, 0 to 2978
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        2979 non-null   int64
#  1   BroadcastName       2976 non-null   object
#  2   Abbreviation        2979 non-null   object
#  3   DriverId            2899 non-null   object
#  4   TeamName            2979 non-null   object
#  5   TeamColor           2976 non-null   object
#  6   TeamId              2899 non-null   object
#  7   FirstName           2979 non-null   object
#  8   LastName            2979 non-null   object
#  9   FullName            2979 non-null   object
#  10  HeadshotUrl         2354 non-null   object
#  11  CountryCode         1357 non-null   object
#  12  Position            2896 non-null   float64
#  13  ClassifiedPosition  2899 non-null   object
#  14  GridPosition        2896 non-null   float64
#  15  Q1                  0 non-null      float64
#  16  Q2                  0 non-null      float64
#  17  Q3                  0 non-null      float64
#  18  Time                1798 non-null   object
#  19  Status              2899 non-null   object
#  20  Points              2899 non-null   float64
#  21  Event               2979 non-null   object
#  22  Year                2979 non-null   int64
#  23  Finished            2979 non-null   bool
#  24  DNF                 2979 non-null   bool
# dtypes: bool(2), float64(6), int64(2), object(15)
# memory usage: 541.2+ KB

# %%
complete_results[complete_results['DriverId'].isna()]['Event'].value_counts()
# Out:
# Event
# Hungarian Grand Prix    20
# Belgian Grand Prix      20
# Dutch Grand Prix        20
# Italian Grand Prix      20
# Name: count, dtype: int64

# %% [markdown]
# There are multiple missing values for all drivers in 4 2024 races. To be investigated ...

# %%
complete_results = pd.concat(results)
complete_results.info()
# Out:
# <class 'fastf1.core.SessionResults'>
# Index: 2979 entries, 5 to 11
# Data columns (total 23 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   DriverNumber        2979 non-null   object
#  1   BroadcastName       2979 non-null   object
#  2   Abbreviation        2979 non-null   object
#  3   DriverId            2979 non-null   object
#  4   TeamName            2979 non-null   object
#  5   TeamColor           2979 non-null   object
#  6   TeamId              2979 non-null   object
#  7   FirstName           2979 non-null   object
#  8   LastName            2979 non-null   object
#  9   FullName            2979 non-null   object
#  10  HeadshotUrl         2979 non-null   object
#  11  CountryCode         2979 non-null   object
#  12  Position            2896 non-null   float64
#  13  ClassifiedPosition  2979 non-null   object
#  14  GridPosition        2896 non-null   float64
#  15  Q1                  0 non-null      timedelta64[ns]
#  16  Q2                  0 non-null      timedelta64[ns]
#  17  Q3                  0 non-null      timedelta64[ns]
#  18  Time                1798 non-null   timedelta64[ns]
#  19  Status              2979 non-null   object
#  20  Points              2899 non-null   float64
#  21  Event               2979 non-null   object
#  22  Year                2979 non-null   int64
# dtypes: float64(3), int64(1), object(15), timedelta64[ns](4)
# memory usage: 558.6+ KB

# %%
complete_results['Status'].value_counts()
# Out:
# Status
# Finished            1633
# +1 Lap               536
# Lapped               182
# +2 Laps              101
# Retired               89
#                       80
# Collision             77
# Accident              35
# Engine                31
# Collision damage      29
# Brakes                20
# Power Unit            16
# Gearbox               15
# +3 Laps               12
# Suspension            10
# Disqualified           9
# Hydraulics             8
# Power loss             8
# Wheel                  7
# Did not start          6
# Puncture               6
# Withdrew               5
# Spun off               4
# Water pressure         4
# Overheating            4
# Oil leak               4
# Fuel pressure          4
# Exhaust                4
# Mechanical             3
# Electronics            3
# Turbo                  3
# Undertray              3
# Water leak             2
# Illness                2
# Transmission           2
# Damage                 2
# Electrical             2
# +5 Laps                1
# Debris                 1
# Steering               1
# Differential           1
# +6 Laps                1
# Out of fuel            1
# Fuel pump              1
# Vibrations             1
# Front wing             1
# Fuel leak              1
# Water pump             1
# Cooling system         1
# Rear wing              1
# Battery                1
# Wheel nut              1
# Tyre                   1
# Radiator               1
# Driveshaft             1
# Name: count, dtype: int64

# %%
complete_results['DNF'] = complete_results.apply(lambda row: False if row['Status'] in ['Finished', '+1 Lap',
                                                                                            '+2 Laps', '+3 Laps', '+4 Laps', '+5 Laps', '+6 Laps',
                                                                                            'Lapped'] else True, axis=1)

# %%
# Group by DriverId and aggregate the required information
driver_summary = complete_results.groupby('FullName').agg(
    # Calculate the sum of 'Points' for each driver
    TotalPoints=('Points', 'sum'),

    # Count the total number of race result entries for each driver
    NumberOfStarts=('DriverId', 'size'),
    
    # Number of races with a DNF
    NumberOfDNF=('DNF', lambda x: x.sum()),
    
    # DNF percentage
    DNF_Percentage=('DNF', lambda x: x.sum() / len(x)),

    # Collect a unique list of 'TeamId's each driver has raced for
    TeamIds=('TeamId', lambda x: list(x.unique())),
    
    # Lowest grid position
    LowestFinishPosition=('Position', 'min'),

    # Highest grid position
    HighestFinishPosition=('Position', 'max'),
    
    # Average grid position
    AverageFinishPosition=('Position', 'mean'),    
    
    # Number of wins
    NumberOfWins=('ClassifiedPosition', lambda x: (x == '1').sum()),
    
    # Number of podiums
    #NumberOfPodiums=('ClassifiedPosition', lambda x: (x.astype(int) <= 3).sum()),
    
    # Number of poles
    #NumberOfPoles=('ClassifiedPosition', lambda x: (x.astype(int) == 1).sum()),
    
    
).reset_index() # Convert the grouped 'DriverId' back into a column

# Optional: Sort the summary table by TotalPoints in descending order
driver_summary = driver_summary.sort_values(by='TotalPoints', ascending=False)

# Display the resulting summary table
print("Driver Summary Table:")
print(driver_summary)

# Display info about the summary table structure
print("\nSummary Table Info:")
driver_summary.info()
# Out:
# Driver Summary Table:
#               FullName  TotalPoints  NumberOfStarts  NumberOfDNF  \
# 22      Max Verstappen       2443.5             149           21
# 18      Lewis Hamilton       2156.5             148           12
# 4      Charles Leclerc       1296.0             149           28
# 36        Sergio Perez       1093.0             147           22
# 38     Valtteri Bottas       1072.0             149           24
# 3         Carlos Sainz       1047.5             148           23
# 17        Lando Norris        880.0             128           15
# 34    Sebastian Vettel        673.0             101           14
# 10      George Russell        647.0             128           21
# 5     Daniel Ricciardo        503.0             128           25
# 8      Fernando Alonso        475.0             111           23
# 30        Pierre Gasly        424.0             149           26
# 7         Esteban Ocon        351.0             127           27
# 15      Kimi Räikkönen        308.0              79            9
# 29       Oscar Piastri        274.0              46            7
# 16        Lance Stroll        245.0             148           29
# 0      Alexander Albon        236.0             105           23
# 25     Nico Hulkenberg        158.0              93           20
# 14     Kevin Magnussen        114.0             125           26
# 39        Yuki Tsunoda         85.0              90           19
# 6         Daniil Kvyat         69.0              38            5
# 33     Romain Grosjean         47.0              57           16
# 1   Antonio Giovinazzi         21.0              60            6
# 11         Guanyu Zhou         16.0              68           13
# 23     Mick Schumacher         12.0              44            6
# 37   Stoffel Vandoorne         12.0              21            3
# 24     Nicholas Latifi          9.0              61           13
# 21     Marcus Ericsson          9.0              21            4
# 28      Oliver Bearman          7.0               3            0
# 19         Liam Lawson          6.0              11            0
# 9     Franco Colapinto          5.0               9            4
# 2      Brendon Hartley          4.0              21            7
# 27       Nyck De Vries          2.0              11            1
# 32       Robert Kubica          1.0              23            2
# 35     Sergey Sirotkin          1.0              21            3
# 20      Logan Sargeant          1.0              36           10
# 13         Jack Doohan          0.0               1            0
# 26      Nikita Mazepin          0.0              22            6
# 12         Jack Aitken          0.0               1            0
# 31   Pietro Fittipaldi          0.0               2            0
#
#     DNF_Percentage                                         TeamIds  \
# 22        0.140940                                    [red_bull, ]
# 18        0.081081                                    [mercedes, ]
# 4         0.187919                             [sauber, ferrari, ]
# 36        0.149660         [force_india, racing_point, red_bull, ]
# 38        0.161074                      [mercedes, alfa, sauber, ]
# 3         0.155405                   [renault, mclaren, ferrari, ]
# 17        0.117188                                     [mclaren, ]
# 34        0.138614                         [ferrari, aston_martin]
# 10        0.164062                          [williams, mercedes, ]
# 5         0.195312  [red_bull, renault, mclaren, alphatauri, rb, ]
# 8         0.207207               [mclaren, alpine, aston_martin, ]
# 30        0.174497    [toro_rosso, red_bull, alphatauri, alpine, ]
# 7         0.212598                [force_india, renault, alpine, ]
# 15        0.113924                                 [ferrari, alfa]
# 29        0.152174                                     [mclaren, ]
# 16        0.195946        [williams, racing_point, aston_martin, ]
# 0         0.219048              [toro_rosso, red_bull, williams, ]
# 25        0.215054   [renault, racing_point, aston_martin, haas, ]
# 14        0.208000                                        [haas, ]
# 39        0.211111                              [alphatauri, rb, ]
# 6         0.131579                        [toro_rosso, alphatauri]
# 33        0.280702                                          [haas]
# 1         0.100000                                          [alfa]
# 11        0.191176                                [alfa, sauber, ]
# 23        0.136364                                          [haas]
# 37        0.142857                                       [mclaren]
# 24        0.213115                                      [williams]
# 21        0.190476                                        [sauber]
# 28        0.000000                                 [ferrari, haas]
# 19        0.000000                                [alphatauri, rb]
# 9         0.444444                                    [, williams]
# 2         0.333333                                    [toro_rosso]
# 27        0.090909                          [williams, alphatauri]
# 32        0.086957                                [williams, alfa]
# 35        0.142857                                      [williams]
# 20        0.277778                                    [williams, ]
# 13        0.000000                                        [alpine]
# 26        0.272727                                          [haas]
# 12        0.000000                                      [williams]
# 31        0.000000                                          [haas]
#
#     LowestFinishPosition  HighestFinishPosition  AverageFinishPosition  \
# 22                   1.0                   20.0               4.275862
# 18                   1.0                   20.0               4.368056
# 4                    1.0                   20.0               7.689655
# 36                   1.0                   20.0               8.230769
# 38                   1.0                   20.0               9.179310
# 3                    1.0                   20.0               8.125000
# 17                   1.0                   20.0               8.016129
# 34                   1.0                   20.0               8.970297
# 10                   1.0                   20.0              10.532258
# 5                    1.0                   20.0              10.661290
# 8                    2.0                   20.0              10.028037
# 30                   1.0                   20.0              11.096552
# 7                    1.0                   20.0              11.162602
# 15                   1.0                   20.0              10.835443
# 29                   1.0                   20.0               8.428571
# 16                   3.0                   20.0              12.286713
# 0                    3.0                   20.0              11.900990
# 25                   5.0                   20.0              12.370787
# 14                   5.0                   20.0              13.966942
# 39                   4.0                   20.0              13.430233
# 6                    3.0                   19.0              11.500000
# 33                   4.0                   20.0              14.210526
# 1                    5.0                   20.0              13.800000
# 11                   8.0                   20.0              14.375000
# 23                   6.0                   20.0              15.558140
# 37                   8.0                   18.0              12.857143
# 24                   7.0                   20.0              15.852459
# 21                   9.0                   20.0              13.190476
# 28                   7.0                   12.0               9.666667
# 19                   9.0                   17.0              12.909091
# 9                    8.0                   19.0              13.750000
# 2                    9.0                   20.0              14.904762
# 27                   9.0                   20.0              15.272727
# 32                  10.0                   20.0              16.782609
# 35                  10.0                   20.0              15.523810
# 20                  10.0                   20.0              16.303030
# 13                  15.0                   15.0              15.000000
# 26                  14.0                   20.0              17.761905
# 12                  16.0                   16.0              16.000000
# 31                  17.0                   19.0              18.000000
#
#     NumberOfWins
# 22            60
# 18            42
# 4              7
# 36             6
# 38             7
# 3              4
# 17             3
# 34             6
# 10             3
# 5              3
# 8              0
# 30             1
# 7              1
# 15             1
# 29             1
# 16             0
# 0              0
# 25             0
# 14             0
# 39             0
# 6              0
# 33             0
# 1              0
# 11             0
# 23             0
# 37             0
# 24             0
# 21             0
# 28             0
# 19             0
# 9              0
# 2              0
# 27             0
# 32             0
# 35             0
# 20             0
# 13             0
# 26             0
# 12             0
# 31             0
#
# Summary Table Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 22 to 31
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   FullName               40 non-null     object
#  1   TotalPoints            40 non-null     float64
#  2   NumberOfStarts         40 non-null     int64
#  3   NumberOfDNF            40 non-null     int64
#  4   DNF_Percentage         40 non-null     float64
#  5   TeamIds                40 non-null     object
#  6   LowestFinishPosition   40 non-null     float64
#  7   HighestFinishPosition  40 non-null     float64
#  8   AverageFinishPosition  40 non-null     float64
#  9   NumberOfWins           40 non-null     int64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 3.4+ KB

# %%
driver_summary.to_csv('driver_summary.csv', index=False)
